# %%
# %pip install faster-whisper psutil pytubefix pandas fastapi spacy numba openai pydub ruff tqdm
# Out:
# ...
#   Using cached faster_whisper-1.2.0-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached pytubefix-9.4.1-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached pandas-2.3.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached fastapi-0.116.1-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached spacy-3.8.7-cp312-cp312-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached numba-0.61.2-cp312-cp312-win_amd64.whl.metadata (2.9 kB)
# ...
#   Using cached openai-1.100.1-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached ruff-0.12.9-py3-none-win_amd64.whl.metadata (26 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached ctranslate2-4.6.0-cp312-cp312-win_amd64.whl.metadata (10 kB)
# ...
#   Using cached huggingface_hub-0.34.4-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached tokenizers-0.21.4-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# ...

# %%
import os

# my_cuda_path = 'B:/Programas/Programming/CUDA/bin'
# my_cuda_path_2 = 'B:/Programas/Programming/CUDA/bin/x64'

# os.environ["PATH"] += os.pathsep + my_cuda_path
# os.environ["PATH"] += os.pathsep + my_cuda_path_2

from numba import cuda

print("CUDA disponível?", cuda.is_available())
# Out:
# CUDA disponível? False
